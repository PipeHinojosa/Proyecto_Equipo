# %%
import pandas as pd

df = pd.read_csv("Base de datos Gómez (Limpia).csv", sep=";")

df.head()
# Out:
# /tmp/ipykernel_1683/3070945878.py:3: DtypeWarning: Columns (1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Base de datos Gómez (Limpia).csv", sep=";")
#    Temporada         Equipo        Jugador Posicion Edad Nacionalidad  \
# 0       2019  CSD Colo-Colo  Brayan Cortés  Portero   23        Chile
# 1       2019  CSD Colo-Colo   Miguel Pinto  Portero   35        Chile
# 2       2019  CSD Colo-Colo  Agustín Orión  Portero   37    Argentina
# 3       2019  CSD Colo-Colo     Darío Melo  Portero   25        Chile
# 4       2019  CSD Colo-Colo  Omar Carabalí  Portero   21        Chile
#
#   Valor de mercado  Unnamed: 7  Unnamed: 8
# 0        600 mil €         NaN         NaN
# 1        500 mil €         NaN         NaN
# 2        500 mil €         NaN         NaN
# 3        300 mil €         NaN         NaN
# 4         50 mil €         NaN         NaN
